# %% [markdown]
# <a href="https://colab.research.google.com/github/guico3lho/NLP_UnB_2022_1/blob/comp1/Comp1_160123046_180025210.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import ast

import regex as re

import base64
import requests

# %%
master = "https://raw.githubusercontent.com/viniciusrpb/cic0269_natural_language_processing/main/resources/SentiLex-lem-PT02.txt"
req = requests.get(master)
req = req.text

classes_dict = {}

for line in req.split("\n"):
      word = re.findall(r'([^.]+)',line)[0]
      PoS = re.search(r'(PoS=)(\w+)',line).group(2)
      classes_dict[word] = PoS

print(classes_dict)
# Out:
# {'à-vontade': 'N', 'abafado': 'Adj', 'abafante': 'Adj', 'abaixado': 'Adj', 'abalado': 'Adj', 'abalizado': 'Adj', 'abalroado': 'Adj', 'abalroar': 'V', 'abanar': 'V', 'abandalhado': 'Adj', 'abandalhamento': 'N', 'abandonado': 'Adj', 'abandonar': 'V', 'abarcante': 'Adj', 'abarrotado': 'Adj', 'abastado': 'Adj', 'abastecido': 'Adj', 'abater': 'V', 'abatido': 'Adj', 'abelhudo': 'Adj', 'abençoado': 'Adj', 'aberração': 'N', 'aberrante': 'Adj', 'aberrativo': 'Adj', 'aberto': 'Adj', 'abespinhado': 'Adj', 'abestalhado': 'Adj', 'abilolado': 'Adj', 'abjeção': 'N', 'abjecção': 'N', 'abjecto': 'Adj', 'abjeto': 'Adj', 'abnegado': 'Adj', 'abobado': 'Adj', 'abobalhado': 'Adj', 'abolicionista': 'Adj', 'abolido': 'Adj', 'abominador': 'Adj', 'abominando': 'Adj', 'abominar': 'V', 'abominável': 'Adj', 'abonado': 'Adj', 'abonatório': 'Adj', 'abonecado': 'Adj', 'aborrecer-se': 'V', 'aborrecer': 'V', 'aborrecido': 'Adj', 'abortado': 'Adj', 'abraçado': 'Adj', 'abrasileirado': 'Adj', 'abrigado': 'Adj', 'abrilhantado': 'Adj', 'abrir a alma': 'IDIOM', 'abrir o coração': 'IDIOM', 'abrir os olhos': 'IDIOM', 'abrupto': 'Adj', 'abrutalhado': 'Adj', 'absentista': 'Adj', 'absolutista': 'Adj', 'absoluto': 'Adj', 'absolvido': 'Adj', 'absorvente': 'Adj', 'abstémico': 'Adj', 'abstémio': 'Adj', 'abstencionista': 'Adj', 'abstinente': 'Adj', 'abstracto': 'Adj', 'abstraído': 'Adj', 'abstrato': 'Adj', 'abstrusidade': 'N', 'abstruso': 'Adj', 'absurdo': 'Adj', 'abulia': 'N', 'abúlico': 'Adj', 'aburguesado': 'Adj', 'abusado': 'Adj', 'abusador': 'Adj', 'abusar': 'V', 'abusivo': 'Adj', 'acabado': 'Adj', 'acabadote': 'Adj', 'acabrunhado': 'Adj', 'acaciano': 'Adj', 'acadêmico': 'Adj', 'acalorado': 'Adj', 'açambarcador': 'Adj', 'acanhado': 'Adj', 'acanhamento': 'N', 'acanhar-se': 'V', 'acatado': 'Adj', 'acatador': 'Adj', 'acautelado': 'Adj', 'acéfalo': 'Adj', 'aceitável': 'Adj', 'aceite': 'Adj', 'aceito': 'Adj', 'acelerado': 'Adj', 'acentuado': 'Adj', 'acerado': 'Adj', 'acerbidade': 'N', 'acerbo': 'Adj', 'acérrimo': 'Adj', 'acertado': 'Adj', 'acertar na mosca': 'IDIOM', 'acertar na mouche': 'IDIOM', 'aceso': 'Adj', 'acessível': 'Adj', 'achacado': 'Adj', 'achado': 'Adj', 'achar piada a': 'IDIOM', 'achatado': 'Adj', 'achegado': 'Adj', 'achincalhar': 'V', 'achinesado': 'Adj', 'acidentado': 'Adj', 'aciganado': 'Adj', 'acintoso': 'Adj', 'acirrado': 'Adj', 'aclamado': 'Adj', 'aclamar': 'V', 'acobardado': 'Adj', 'acobardar-se': 'V', 'acobertado': 'Adj', 'acobreado': 'Adj', 'acocado': 'Adj', 'açoitado': 'Adj', 'acolhedor': 'Adj', 'acolhido': 'Adj', 'acomodadiço': 'Adj', 'acomodar-se': 'V', 'acomodatício': 'Adj', 'acompanhado': 'Adj', 'acompanhador': 'Adj', 'acompanhante': 'Adj', 'aconchegado': 'Adj', 'acordado': 'Adj', 'acordar com o rabo para o ar': 'IDIOM', 'acordar com os pés de fora': 'IDIOM', 'acorrentado': 'Adj', 'acorrentar-se': 'V', 'acorrentar': 'V', 'acossado': 'Adj', 'acossar': 'V', 'acostumado': 'Adj', 'acotovelar': 'V', 'açougueiro': 'Adj', 'acre': 'Adj', 'acreditado': 'Adj', 'acreditar': 'V', 'acriançado': 'Adj', 'acrisolado': 'Adj', 'acrítico': 'Adj', 'activo': 'Adj', 'actualista': 'Adj', 'acudir': 'V', 'aculturado': 'Adj', 'acurado': 'Adj', 'acusado': 'Adj', 'acusar': 'V', 'acutilante': 'Adj', 'adâmico': 'Adj', 'adaptado': 'Adj', 'adepto': 'Adj', 'adequado': 'Adj', 'adestrado': 'Adj', 'adicional': 'Adj', 'adiposo': 'Adj', 'adjacente': 'Adj', 'administrado': 'Adj', 'admirar': 'V', 'admirável': 'Adj', 'admitido': 'Adj', 'admoestador': 'Adj', 'adoentado': 'Adj', 'adorado': 'Adj', 'adorando': 'Adj', 'adorar': 'V', 'adorável': 'Adj', 'adormecido': 'Adj', 'adulador': 'Adj', 'adulterador': 'Adj', 'adulterino': 'Adj', 'adultério': 'N', 'adúltero': 'Adj', 'adulto': 'Adj', 'adventista': 'Adj', 'adverso': 'Adj', 'aéreo': 'Adj', 'afabilidade': 'N', 'afamado': 'Adj', 'afanado': 'Adj', 'afasia': 'N', 'afásico': 'Adj', 'afastar': 'V', 'afável': 'Adj', 'afectado': 'Adj', 'afectar': 'V', 'afectividade': 'N', 'afectivo': 'Adj', 'afecto': 'N', 'afectuoso': 'Adj', 'afeiçoado': 'Adj', 'afeit ...

# %%
def normalizarString(text):
	import unicodedata
	try:
		text = unicode(text, 'utf-8')
	except NameError:
		pass
	text = unicodedata.normalize('NFD', text).encode('ascii', 'ignore').decode("utf-8")
	return str(text.lower())

# %%
def main():
    master = "https://raw.githubusercontent.com/viniciusrpb/cic0269_natural_language_processing/main/resources/SentiLex-lem-PT02.txt"
    req = requests.get(master)
    req = req.text

    classes_dict = {}

    for line in req.split("\n"):
         word = re.findall(r'([^.]+)',line)[0]
         PoS = re.search(r'(PoS=)(\w+)',line).group(2)
         classes_dict[word] = PoS


    df = pd.read_csv(
            'https://raw.githubusercontent.com/viniciusrpb/cic0269_natural_language_processing/main/datasets/corpora/training.csv')

    print("\n")

    corpus_dict = {}
    for row in df.iterrows():
            corpus_dict['texto {}'.format(row[0])] = {}
            text = row[1]['text']
            text = normalizarString(text)
            text_words = text.split() # ['oi', 'tchau']
            for i,word in enumerate(text_words):
                if word in classes_dict:
                    corpus_dict['texto {}'.format(row[0])][word] = classes_dict[word]
    print(corpus_dict)

# %%
if __name__ == "__main__":
    main()
# Out:
# {'texto 0': {'bom': 'Adj', 'manha': 'N', 'interessante': 'Adj'}, 'texto 1': {}, 'texto 2': {}, 'texto 3': {'conservado': 'Adj'}, 'texto 4': {'bom': 'Adj'}, 'texto 5': {'condicionado': 'Adj', 'antigo': 'Adj', 'manha': 'N'}, 'texto 6': {'gentil': 'Adj', 'manha': 'N'}, 'texto 7': {'pior': 'Adj'}, 'texto 8': {'antigo': 'Adj', 'bom': 'Adj'}, 'texto 9': {'manha': 'N', 'melhor': 'Adj'}, 'texto 10': {'manha': 'N'}, 'texto 11': {'simples': 'Adj', 'manha': 'N'}, 'texto 12': {'diminuir': 'V'}, 'texto 13': {}, 'texto 14': {'manha': 'N'}, 'texto 15': {'bom': 'Adj', 'antigo': 'Adj'}, 'texto 16': {'bom': 'Adj', 'justo': 'Adj'}, 'texto 17': {'simples': 'Adj', 'determinado': 'Adj', 'atrativo': 'Adj'}, 'texto 18': {'maravilhoso': 'Adj', 'cheiroso': 'Adj', 'alto': 'Adj'}, 'texto 19': {'fedor': 'N', 'manha': 'N', 'barulhento': 'Adj'}, 'texto 20': {'bom': 'Adj', 'manha': 'N'}, 'texto 21': {'manha': 'N', 'vergonhoso': 'Adj', 'pior': 'Adj'}, 'texto 22': {'condicionado': 'Adj'}, 'texto 23': {'bom': 'Adj', 'ruim': 'Adj'}, 'texto 24': {'melhor': 'Adj', 'forte': 'Adj', 'ilustre': 'Adj', 'manha': 'N'}, 'texto 25': {}, 'texto 26': {'limpo': 'Adj', 'bom': 'Adj', 'excelente': 'Adj'}, 'texto 27': {'excelente': 'Adj'}, 'texto 28': {'excelente': 'Adj'}, 'texto 29': {'atencioso': 'Adj', 'cordial': 'Adj'}, 'texto 30': {'excelente': 'Adj', 'bom': 'Adj', 'recomendado': 'Adj'}, 'texto 31': {'manha': 'N', 'bom': 'Adj'}, 'texto 32': {}, 'texto 33': {'condicionado': 'Adj', 'assustado': 'Adj', 'manha': 'N', 'absurdo': 'Adj', 'usar': 'V'}, 'texto 34': {'manha': 'N', 'demorado': 'Adj'}, 'texto 35': {'bom': 'Adj', 'perigoso': 'Adj'}, 'texto 36': {'bom': 'Adj', 'manha': 'N', 'absurdo': 'Adj', 'direto': 'Adj'}, 'texto 37': {'bom': 'Adj', 'manha': 'N'}, 'texto 38': {'quente': 'Adj', 'resolvido': 'Adj', 'manha': 'N'}, 'texto 39': {'manha': 'N', 'excelente': 'Adj'}, 'texto 40': {}, 'texto 41': {}, 'texto 42': {'bom': 'Adj', 'manha': 'N'}, 'texto 43': {'bom': 'Adj', 'manha': 'N'}, 'texto 44': {'manha': 'N', 'bom': 'Adj', 'quente': 'Adj', 'problema': 'N'}, 'texto 45': {'interessante': 'Adj', 'bom': 'Adj'}, 'texto 46': {}, 'texto 47': {'manha': 'N', 'bom': 'Adj'}, 'texto 48': {'bom': 'Adj', 'excelente': 'Adj', 'manha': 'N', 'direto': 'Adj'}, 'texto 49': {'excelente': 'Adj'}, 'texto 50': {'agilidade': 'N'}, 'texto 51': {}, 'texto 52': {'bom': 'Adj', 'manha': 'N'}, 'texto 53': {'manha': 'N'}, 'texto 54': {'excelente': 'Adj'}, 'texto 55': {'excelente': 'Adj'}, 'texto 56': {}, 'texto 57': {'bom': 'Adj', 'manha': 'N'}, 'texto 58': {}, 'texto 59': {'condicionado': 'Adj', 'manha': 'N', 'ruim': 'Adj'}, 'texto 60': {'simples': 'Adj', 'problema': 'N', 'condicionado': 'Adj'}, 'texto 61': {'problema': 'N', 'condicionado': 'Adj', 'manha': 'N'}, 'texto 62': {'simples': 'Adj', 'bom': 'Adj'}, 'texto 63': {'excelente': 'Adj', 'bom': 'Adj', 'manha': 'N'}, 'texto 64': {'manha': 'N'}, 'texto 65': {'bom': 'Adj', 'simpatia': 'N'}, 'texto 66': {'fechado': 'Adj', 'dado': 'Adj'}, 'texto 67': {'bom': 'Adj', 'limpo': 'Adj'}, 'texto 68': {'manha': 'N', 'quente': 'Adj', 'problema': 'N', 'resolvido': 'Adj'}, 'texto 69': {'respeito': 'N', 'fraco': 'Adj'}, 'texto 70': {'antigo': 'Adj'}, 'texto 71': {'condicionado': 'Adj', 'velho': 'Adj', 'barulhento': 'Adj', 'manha': 'N'}, 'texto 72': {'antigo': 'Adj', 'ideal': 'Adj', 'bom': 'Adj', 'barato': 'Adj'}, 'texto 73': {'velho': 'Adj', 'melhor': 'Adj'}, 'texto 74': {'problema': 'N', 'vantagem': 'N'}, 'texto 75': {'manha': 'N'}, 'texto 76': {'deficiente': 'Adj', 'forte': 'Adj'}, 'texto 77': {'problema': 'N', 'manha': 'N', 'barulhento': 'Adj'}, 'texto 78': {}, 'texto 79': {'condicionado': 'Adj', 'bom': 'Adj', 'distante': 'Adj', 'manha': 'N'}, 'texto 80': {'limpo': 'Adj', 'manha': 'N'}, 'texto 81': {'simples': 'Adj', 'limpo': 'Adj', 'manha': 'N'}, 'texto 82': {'quente': 'Adj', 'manha': 'N', 'bom': 'Adj'}, 'texto 83': {'antigo': 'Adj', 'moderno': 'Adj', 'limpo': 'Adj', 'manha': 'N'}, 'texto 84': {'bom': 'Adj'}, 'texto 85': {'manha': 'N', 'condicionado': 'Adj', 'irritante': ...
